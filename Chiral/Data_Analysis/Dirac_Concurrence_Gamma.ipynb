# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
df_Concurrence_O = pd.read_csv(r'Concurrence/Dirac_Concurrence_O_Gamma.txt', sep='\t', header = None)
df_Concurrence_U = pd.read_csv(r'Concurrence/Dirac_Concurrence_U_Gamma.txt', sep='\t', header = None)

df_Entanglement_O = pd.read_csv(r'Concurrence/Dirac_Entanglement_O_Gamma.txt', sep='\t', header = None)
df_Entanglement_U = pd.read_csv(r'Concurrence/Dirac_Entanglement_U_Gamma.txt', sep='\t', header = None)

# %%
df_Concurrence_O.rename(columns = lambda s: (s/20))
# Out:
#             0.00      0.05      0.10      0.15      0.20      0.25      0.30  \
# 0       0.056248  0.792861  0.020590  0.992586  0.872368  0.729357  0.701354
# 1       0.951157  0.997237  0.258505  0.438204  0.975427  0.007301  0.742466
# 2       0.589937  0.145360  0.841231  0.510570  0.574099  0.902156  0.005207
# 3       0.708980  0.900786  0.476868  0.983098  0.382587  0.282576  0.800817
# 4       0.951951  0.051187  0.531753  0.594090  0.697246  0.994532  0.877385
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0.988016  0.974029  0.248782  0.142536  0.817902  0.590297  0.998154
# 999996  0.151414  0.197355  0.918214  0.244228  0.361494  0.346516  0.777243
# 999997  0.465299  0.998509  0.489663  0.394818  0.498109  0.945739  0.987826
# 999998  0.006829  0.984406  0.833785  0.075016  0.885587  0.518452  0.854191
# 999999  0.007200  0.001064  0.487902  0.353616  0.406154  0.504376  0.780908
#
# ...

# %%
df_Entanglement_O.dropna(inplace = True)
df_Entanglement_U.dropna(inplace = True)
df_Entanglement_O.rename(columns = lambda s: (s/20))
# Out:
#             0.00      0.05      0.10      0.15      0.20      0.25      0.30  \
# 0       0.009297  0.712425  0.001552  0.989317  0.819995  0.629342  0.593573
# 1       0.930120  0.996016  0.124219  0.288781  0.964696  0.000235  0.646274
# 2       0.457077  0.047773  0.777422  0.366229  0.438492  0.861237  0.000126
# 3       0.603260  0.859330  0.329476  0.975685  0.233234  0.143555  0.723018
# 4       0.931246  0.007877  0.389905  0.461985  0.588372  0.992119  0.826907
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0.982746  0.962696  0.116684  0.046216  0.745896  0.457502  0.997338
# 999996  0.051174  0.079690  0.883671  0.113211  0.213166  0.199273  0.691748
# 999997  0.317130  0.997849  0.343293  0.245130  0.352506  0.922441  0.982472
# 999998  0.000208  0.977561  0.767325  0.015375  0.838236  0.374988  0.795075
# 999999  0.000229  0.000007  0.341382  0.205822  0.256319  0.359389  0.696587
#
# ...

# %%
Concurrence_O = df_Concurrence_O.values
Concurrence_U = df_Concurrence_U.values

Entanglement_O = df_Entanglement_O.values
Entanglement_U = df_Entanglement_U.values

# %%
def Concurrence_distribution_O(x):
    for i in range(len(x)):
        p_O_x[i] = 2/((1+x[i])**2)
    return p_O_x

def Concurrence_distribution_U(x):
    for i in range(len(x)):
        p_U_x[i] = ((2*x[i])/(1-(x[i]**2))**3)*(3*(2+3*x[i]**2)*np.arctanh(np.sqrt(1-x[i]**2))-(11+4*x[i]**2)*np.sqrt(1-x[i]**2))
    return p_U_x
        
fig, axs = plt.subplots(2,4, figsize = (14,6), constrained_layout = True)

fig.suptitle(r'DISTRIBUTION OF CONCURRENCE AS FUNCTION OF $\Gamma$ (N = 2)', fontsize = 20)

for j in range(0,4):
    
    gamma_idx = 5*j+5
    
    gamma_value = 0.25*gamma_idx/5
    
    axs[0,j].hist(Concurrence_O[:,gamma_idx], bins = 30, color='dodgerblue', label = r'$\beta = 1$', alpha=1, density = True, histtype='bar', ec='black');
    axs[1,j].hist(Concurrence_U[:,gamma_idx], bins = 30, color='red', label = r'$\beta = 2$', alpha=1, density = True, histtype='bar', ec='black');
    
    axs[0,j].set_title(r'$\Gamma = $'+ str(gamma_value), fontsize = 18)
    
    axs[0,0].set_ylabel(r'$\mathcal{P}_{1}(\mathcal{C})$', fontsize = 18)
    axs[1,0].set_ylabel(r'$\mathcal{P}_{2}(\mathcal{C})$', fontsize = 18)
    
    if (j == 3):
        x = [i/100 for i in range(0,100)]
        p_O_x = [[] for i in range(0,100)]
        p_U_x = [[] for i in range(0,100)]
        p_O_x = Concurrence_distribution_O(x)
        p_U_x = Concurrence_distribution_U(x)
        #axs[0,j].plot(x, p_O_x, color = 'black', label = r'$\mathcal{P}_{1}(\mathcal{C})$', linestyle = 'dashed', linewidth = 2)
        #axs[1,j].plot(x, p_U_x, color = 'black', label = r'$\mathcal{P}_{2}(\mathcal{C})$', linestyle = 'dashed', linewidth = 2)
        axs[0,3].legend(fontsize = 15, loc = 'upper right')
        axs[1,3].legend(fontsize = 15, loc = 'upper right')
        
    for i in range(0,2):
        axs[i,0].legend(fontsize = 20)
        axs[i,j].grid(linestyle=':')
        axs[i,j].tick_params(axis = 'both', which = 'major', labelsize = 12)
# Out:
# <ipython-input-151-32748bf43d13>:8: RuntimeWarning: divide by zero encountered in arctanh
#   p_U_x[i] = ((2*x[i])/(1-(x[i]**2))**3)*(3*(2+3*x[i]**2)*np.arctanh(np.sqrt(1-x[i]**2))-(11+4*x[i]**2)*np.sqrt(1-x[i]**2))
# <ipython-input-151-32748bf43d13>:8: RuntimeWarning: invalid value encountered in double_scalars
#   p_U_x[i] = ((2*x[i])/(1-(x[i]**2))**3)*(3*(2+3*x[i]**2)*np.arctanh(np.sqrt(1-x[i]**2))-(11+4*x[i]**2)*np.sqrt(1-x[i]**2))

# %%
fig, axs = plt.subplots(2,4, figsize = (14,6), constrained_layout = True)

fig.suptitle(r'DISTRIBUTION OF ENTANGLEMENT OF FORMATION AS FUNCTION OF $\Gamma$ (N = 2)', fontsize = 20)

for j in range(0,4):
    
    gamma_idx = 5*j+5
    
    gamma_value = 0.25*gamma_idx/5
    
    axs[0,j].hist(Entanglement_O[:,gamma_idx], bins = 30, color='dodgerblue', label = r'$\beta = 1$', alpha=1, density = True, histtype='bar', ec='black');
    axs[1,j].hist(Entanglement_U[:,gamma_idx], bins = 30, color='red', label = r'$\beta = 2$', alpha=1, density = True, histtype='bar', ec='black');
    
    axs[0,j].set_title(r'$\Gamma = $'+ str(gamma_value), fontsize = 18)
    
    axs[0,0].set_ylabel(r'$\mathcal{P}_{1}(\mathcal{E})$', fontsize = 18)
    axs[1,0].set_ylabel(r'$\mathcal{P}_{2}(\mathcal{E})$', fontsize = 18)
    
    for i in range(0,2):
        axs[i,0].legend(fontsize = 20)
        axs[i,j].grid(linestyle=':')
        axs[i,j].tick_params(axis = 'both', which = 'major', labelsize = 12)

# %%
fig, axs = plt.subplots(1,2, figsize = (12,6), constrained_layout = True)

fig.suptitle(r'SCATTER OF THE DISTRIBUTION OF CONCURRENCE AS FUNCTION OF $\Gamma$ (N = 2)', fontsize = 20)

for j in range(0,5):
    
    gamma_idx = 5*j
    
    gamma_value = 0.25*gamma_idx/5
    
    counts_O, bin_edges_O = np.histogram(Concurrence_O[:,gamma_idx], bins = 15, density = True)
    counts_U, bin_edges_U = np.histogram(Concurrence_U[:,gamma_idx], bins = 15, density = True)
    
    axs[0].scatter(bin_edges_O[1:], counts_O, color = 'dodgerblue', alpha = (j+2)/6)
    axs[0].plot(bin_edges_O[1:], counts_O, color = 'dodgerblue', alpha = (j+2)/6, label = r'$\Gamma$ ='+str(gamma_value))

    axs[1].scatter(bin_edges_U[0:len(bin_edges_U)-1], counts_U, color = 'red', alpha = (j+2)/6)
    axs[1].plot(bin_edges_U[0:len(bin_edges_U)-1], counts_U, color = 'red', alpha = (j+2)/6, label = r'$\Gamma$ ='+str(gamma_value))
    
    for i in range(0,2):
    
        axs[i].legend(fontsize = 20)
        axs[i].set_xlabel(r'$\mathcal{C}$', fontsize = 20)
        axs[i].set_ylabel(r'$P_{\beta}(\mathcal{C})$', fontsize = 20)
        axs[i].tick_params(axis = 'both', which = 'major', labelsize = 18)
        axs[i].grid(linestyle=':')

# %%
fig, axs = plt.subplots(1,2, figsize = (12,6), constrained_layout = True)

fig.suptitle(r'SCATTER OF THE DISTRIBUTION OF ENTANGLEMENT AS FUNCTION OF $\Gamma$ (N = 2)', fontsize = 20)

for j in range(0,5):
    
    gamma_idx = 5*j
    
    gamma_value = 0.25*gamma_idx/5
    
    counts_O, bin_edges_O = np.histogram(Entanglement_O[:,gamma_idx], bins = 15, density = True)
    counts_U, bin_edges_U = np.histogram(Entanglement_U[:,gamma_idx], bins = 15, density = True)

    axs[0].scatter(bin_edges_O[1:], counts_O, color = 'dodgerblue', alpha = (j+2)/6)
    axs[0].plot(bin_edges_O[1:], counts_O, color = 'dodgerblue', alpha = (j+2)/6, label = r'$\Gamma$ ='+str(gamma_value))

    axs[1].scatter(bin_edges_U[0:len(bin_edges_U)-1], counts_U, color = 'red', alpha = (j+2)/6)
    axs[1].plot(bin_edges_U[0:len(bin_edges_U)-1], counts_U, color = 'red', alpha = (j+2)/6, label = r'$\Gamma$ ='+str(gamma_value))
    
    for i in range(0,2):
    
        axs[i].legend(fontsize = 20)
        axs[i].set_xlabel(r'$\mathcal{E}$', fontsize = 20)
        axs[i].set_ylabel(r'$P_{\beta}(\mathcal{E})$', fontsize = 20)
        axs[i].tick_params(axis = 'both', which = 'major', labelsize = 18)
        axs[i].grid(linestyle=':')

# %%
meanConcurrence_O = np.mean(Concurrence_O, axis = 0)
meanConcurrence_U = np.mean(Concurrence_U, axis = 0)

varConcurrence_O = np.var(Concurrence_O, axis = 0)
varConcurrence_U = np.var(Concurrence_U, axis = 0)


meanEntanglement_O = np.mean(Entanglement_O, axis = 0)
meanEntanglement_U = np.mean(Entanglement_U, axis = 0)

varEntanglement_O = np.var(Entanglement_O, axis = 0)
varEntanglement_U = np.var(Entanglement_U, axis = 0)

# %%
print("Mean of orthogonal concurrence distribution: " + str(meanConcurrence_O[20]))
print("Mean of unitary concurrence distribution: " + str(meanConcurrence_U[20]))

print("\nVariance of orthogonal concurrence distribution: " + str(varConcurrence_O[20]))
print("Variance of unitary concurrence distribution: " + str(varConcurrence_U[20]))

print("\nMean of orthogonal entanglement distribution: " + str(meanEntanglement_O[20]))
print("Mean of unitary entanglement distribution: " + str(meanEntanglement_U[20]))

print("\nVariance of orthogonal entanglement distribution: " + str(varEntanglement_O[20]))
print("Variance of unitary entanglement distribution: " + str(varEntanglement_U[20]))
# Out:
# Mean of orthogonal concurrence distribution: 0.4720518005567796
# Mean of unitary concurrence distribution: 0.5713579927464726
#
# Variance of orthogonal concurrence distribution: 0.11165148836244
# Variance of unitary concurrence distribution: 0.10330357386639459
#
# Mean of orthogonal entanglement distribution: 0.3870084703585927
# Mean of unitary entanglement distribution: 0.4868980254298986
#
# Variance of orthogonal entanglement distribution: 0.12195847768185845
# Variance of unitary entanglement distribution: 0.12220264161679742

# %%
fig, axs = plt.subplots(1,2, figsize = (15,6), constrained_layout = True)

fig.suptitle(r'MEAN AND VARIANCE OF CONCURRENCE AS FUNCTION OF $\Gamma$', fontsize = 20)

for j in range(0,2):
        
    if (j == 0):
        axs[0].set_title('MEAN', fontsize = 20)
        axs[0].set_ylabel(r'$<\mathcal{C}>$', fontsize = 20)
            
        variable_O = meanConcurrence_O; variable_U = meanConcurrence_U
            
    else:
        axs[1].set_title('VARIANCE', fontsize = 20)
        axs[1].set_ylabel(r'$var(\mathcal{C})$', fontsize = 20)
            
        variable_O = varConcurrence_O; variable_U = varConcurrence_U
    
    for k in range(0,len(meanConcurrence_O)):
        axs[j].scatter((k)/20, variable_O[k], s = 50, color = 'dodgerblue', alpha = 1)
        axs[j].scatter((k)/20, variable_U[k], s = 50, color = 'red', alpha = 1)
        
    axs[j].plot([i/20 for i in range(0,21)], variable_O, label = r'$\beta = 1$', color = 'dodgerblue', linestyle = '-')
    axs[j].plot([i/20 for i in range(0,21)], variable_U, label = r'$\beta = 2$', color = 'red', linestyle = '-')

    axs[j].grid(linestyle=':')
    axs[0].legend(fontsize = 20)

    axs[j].set_xlabel(r'$\Gamma$', fontsize = 20)
    axs[j].tick_params(axis = 'both', which = 'major', labelsize = 18)

# %%
fig, axs = plt.subplots(1,2, figsize = (15,6), constrained_layout = True)

fig.suptitle(r'MEAN AND VARIANCE OF ENTANGLEMENT OF FORMATION AS FUNCTION OF $\Gamma$', fontsize = 20)

for j in range(0,2):
        
    if (j == 0):
        axs[0].set_title('MEAN', fontsize = 20)
        axs[0].set_ylabel(r'$<\mathcal{E}>$', fontsize = 20)
            
        variable_O = meanEntanglement_O; variable_U = meanEntanglement_U
            
    else:
        axs[1].set_title('VARIANCE', fontsize = 20)
        axs[1].set_ylabel(r'$var(\mathcal{E})$', fontsize = 20)
            
        variable_O = varEntanglement_O; variable_U = varEntanglement_U
    
    for k in range(0,len(meanEntanglement_O)):
        axs[j].scatter((k)/20, variable_O[k], s = 50, color = 'dodgerblue', alpha = 1)
        axs[j].scatter((k)/20, variable_U[k], s = 50, color = 'red', alpha = 1)
        
    axs[j].plot([i/20 for i in range(0,21)], variable_O, label = r'$\beta = 1$', color = 'dodgerblue', linestyle = '-')
    axs[j].plot([i/20 for i in range(0,21)], variable_U, label = r'$\beta = 2$', color = 'red', linestyle = '-')

    axs[j].grid(linestyle=':')
    axs[0].legend(fontsize = 20)

    axs[j].set_xlabel(r'$\Gamma$', fontsize = 20)
    axs[j].tick_params(axis = 'both', which = 'major', labelsize = 18)

# %%
fig, axs = plt.subplots(1,2, figsize = (15,6), constrained_layout = True)

fig.suptitle(r'LOCALIZATION OF CONCURRENCE $\mathcal{C}^{WL}$ AND ENTANGLEMENT OF FORMATION $\mathcal{E}^{WL}$ AS FUNCTION OF $\Gamma$', fontsize = 20)

axs[0].plot([i/20 for i in range(0,21)], (meanConcurrence_O-meanConcurrence_U), color = 'purple', linestyle = '-')
for k in range(0,len(meanConcurrence_O)):
        axs[0].scatter((k)/20, (meanConcurrence_O[k]-meanConcurrence_U[k]), s = 50, color = 'purple', alpha = 1)
    
axs[1].plot([i/20 for i in range(0,21)], (meanEntanglement_O-meanEntanglement_U), color = 'purple', linestyle = '-')
for k in range(0,len(meanConcurrence_O)):
        axs[1].scatter((k)/20, (meanEntanglement_O[k]-meanEntanglement_U[k]), s = 50, color = 'purple', alpha = 1)

axs[0].set_ylabel(r'$\mathcal{C}^{WL}$', fontsize = 20)

axs[1].set_ylabel(r'$\mathcal{E}^{WL}$', fontsize = 20)


for i in range(0,2):
    axs[i].grid(linestyle=':')
    axs[i].set_xlabel(r'$\Gamma$', fontsize = 21)
    axs[i].tick_params(axis = 'both', which = 'major', labelsize = 18)
